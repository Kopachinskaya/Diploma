# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117

# %%
# !git clone https://github.com/SilentzeliBob/som-dst
# Out:
# Cloning into 'som-dst'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 33 (delta 1), reused 0 (delta 0), pack-reused 27
# Unpacking objects: 100% (33/33), 265.70 KiB | 2.99 MiB/s, done.

# %%
# %cd /content/som-dst
# Out:
# /content/som-dst

# %%
# !python create_data.py --main_dir '/content/som-dst/data' --target_path '/content/som-dst/processed_data' --mwz_ver '2.1'
# Out:
# Create WOZ-like dialogues. Get yourself a coffee, this might take a while.
# ...
# Divide dialogues...
# # of dialogues: Train 8420, Val 1000, Test 999

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --data_root '/content/som-dst/processed_data' --save_dir '/content/som-dst/model_folder'  --op_code '4'
# Out:
# pytorch version:  2.0.1+cu118
# ...

# %%
# !python evaluation.py --model_ckpt_path '/content/som-dst/model_folder/model_best.bin' --data_root '/content/som-dst/processed_data'
# Out:
# ------------------------------
# op_code: 4, is_gt_op: False, is_gt_p_state: False, is_gt_gen: False
# Epoch 0 joint accuracy :  0.5309446254071661
# Epoch 0 slot turn accuracy :  0.9736020629749801
# Epoch 0 slot turn F1:  0.9171910941855902
# Epoch 0 op accuracy :  0.9741675714802285
# Epoch 0 op F1 :  {'delete': 0.030501089324618733, 'update': 0.7959107608753526, 'dontcare': 0.3029556650246305, 'carryover': 0.9864975897034028}
# Epoch 0 op hit count :  {'delete': 21, 'update': 7474, 'dontcare': 123, 'carryover': 207712}
# Epoch 0 op all count :  {'delete': 1341, 'update': 10745, 'dontcare': 624, 'carryover': 208330}
# Final Joint Accuracy :  0.37037037037037035
# Final slot turn F1 :  0.9108339131790647
# Latency Per Prediction : 27.757033 ms
# -----------------------------
#
# hotel 0.5154559505409583 0.973776403915519
# train 0.7171922685656155 0.9874646772917451
# restaurant 0.6596113809854268 0.9857737682165246
# attraction 0.66872174270448 0.9873270311001585
# ...

# %%
# !python evaluation.py --model_ckpt_path '/content/som-dst/model_folder/my_model_best.bin' --data_root '/content/som-dst/processed_data'
# Out:
# ------------------------------
# op_code: 4, is_gt_op: False, is_gt_p_state: False, is_gt_gen: False
# Epoch 0 joint accuracy :  0.47068403908794787
# Epoch 0 slot turn accuracy :  0.9690146579804076
# Epoch 0 slot turn F1:  0.8979627740140032
# Epoch 0 op accuracy :  0.970077813970275
# Epoch 0 op F1 :  {'delete': 0.017555705604321403, 'update': 0.7727933541017654, 'dontcare': 0.15416666666666667, 'carryover': 0.9843355638602309}
# Epoch 0 op hit count :  {'delete': 13, 'update': 7442, 'dontcare': 74, 'carryover': 206897}
# Epoch 0 op all count :  {'delete': 1461, 'update': 11172, 'dontcare': 832, 'carryover': 207575}
# Final Joint Accuracy :  0.3033033033033033
# Final slot turn F1 :  0.8863964597377196
# Latency Per Prediction : 27.121655 ms
# -----------------------------
#
# hotel 0.43431221020092736 0.9691009788768804
# train 0.6578501186842998 0.9846501638973757
# restaurant 0.6238723108952117 0.9839000693962615
# attraction 0.6350184956843403 0.986052883956715
# ...
